# %%
from cpymad.madx import Madx

madx = Madx()
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.09.03  (64 bit, Linux)       +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2024.04.25               +
#   + Execution date: 2025.04.11 10:05:10      +
#   ++++++++++++++++++++++++++++++++++++++++++++

# %%
madx.call(file="ibs_clic_dr.mad")
madx.twiss()
# Out:
# ! DATE AND TIME:    06/12/04  03.01.00
#
# !
#
# ! FILE:             clicdrnew.mad
#
# !
#
# ang:=2*3.141592653/100;
#
# GRAD :=0.0;   !-3.058302E-01
#
# LEN := 2.724721E-01;
#
# PPN := LEN ;
#
# GR := -2.605525E-01;
#
# ANG := 0.06283185306;
#
# ++++++ info: ang redefined
# GRAD := 0.0;
#
# ++++++ info: grad redefined
# LEN := 0.2724721;
#
# ++++++ info: len redefined
# LL1 := 0.1078097;
#
# LL2 := 0.1000031;
#
# LL3 := 0.07005689;
#
# LL33 := 0.14011378;
#
# KS1Y1 := -1.077126318641E4;
#
# KS1X2 := 8.762601512321E3;
#
# KS3Y1 := -1.078690067568E4;
#
# KS3X2 := 8.762602111656E3;
#
# KS2Y1 := -1.078016140083E4;
#
# KS2X2 := 8.762601901965E3;
#
# KS1X3 := 8.762602063503E3;
#
# KS2X3 := 8.762601957832E3;
#
# KS3X3 := 8.762601481058E3;
#
# WIGGLERPEAKFIELD := 1.764;
#
# WIGGLERPERIOD := 0.2;
#
# POLELENGTH := WIGGLERPERIOD/4.0;
#
# WIGANGLE := 0.011155944;
#
# PPN := LEN;
#
# ++++++ info: ppn redefined
# GR := -0.2605525;
#
# ++++++ info: gr redefined
# ALFA2 := -3.561549;
#
# ...

# %%
madx.
