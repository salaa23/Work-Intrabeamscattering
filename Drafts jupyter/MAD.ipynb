# %%
from cpymad.madx import Madx

madx = Madx()
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.09.03  (64 bit, Linux)       +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2024.04.25               +
#   + Execution date: 2025.04.15 14:21:08      +
#   ++++++++++++++++++++++++++++++++++++++++++++

# %%
madx.call(file="ibs/ClicDampingRing/ibs_clic_dr.mad")
# madx.twiss()
# Out:
# ! DATE AND TIME:    06/12/04  03.01.00
#
# !
#
# ! FILE:             clicdrnew.mad
#
# !
#
# ang:=2*3.141592653/100;
#
# GRAD :=0.0;   !-3.058302E-01
#
# LEN := 2.724721E-01;
#
# PPN := LEN ;
#
# GR := -2.605525E-01;
#
# ANG := 0.06283185306;
#
# ++++++ info: ang redefined
# GRAD := 0.0;
#
# ++++++ info: grad redefined
# LEN := 0.2724721;
#
# ++++++ info: len redefined
# LL1 := 0.1078097;
#
# LL2 := 0.1000031;
#
# LL3 := 0.07005689;
#
# LL33 := 0.14011378;
#
# KS1Y1 := -1.077126318641E4;
#
# KS1X2 := 8.762601512321E3;
#
# KS3Y1 := -1.078690067568E4;
#
# KS3X2 := 8.762602111656E3;
#
# KS2Y1 := -1.078016140083E4;
#
# KS2X2 := 8.762601901965E3;
#
# KS1X3 := 8.762602063503E3;
#
# KS2X3 := 8.762601957832E3;
#
# KS3X3 := 8.762601481058E3;
#
# WIGGLERPEAKFIELD := 1.764;
#
# WIGGLERPERIOD := 0.2;
#
# POLELENGTH := WIGGLERPERIOD/4.0;
#
# WIGANGLE := 0.011155944;
#
# PPN := LEN;
#
# ++++++ info: ppn redefined
# GR := -0.2605525;
#
# ++++++ info: gr redefined
# ALFA2 := -3.561549;
#
# ...

# %%
from cpymad.madx import Madx

mad = Madx()
mad.options.echo = True
mad.options.warn = True

# Load your lattice or define a simple one
mad.call("heb_ring_withcav.seq")  # Or define sequence here directly

# Use beam parameters
mad.input("""
beam, particle=electron, energy=45.6, npart=2500000000000.0, ex=9.99e-6, ey=9.99e-6, et=0.004, sige=0.001;
use, sequence=your_sequence;

twiss;
""")

# IBS module (using MAD-X's internal method)
# mad.input("""
# ibs, model=madx, tol=1e-10, maxiter=100;
# """)
# mad.input("""
# ! Re-run TWISS to make sure optics are updated
# twiss;

# ! Call IBS with explicit parameters
# ibs, model=madx, 
#      tol=1e-10,
#      maxiter=100,
#      method=standard,
#      longitudinal=true,
#      transverse=true;
# """)



# Output results
tw = mad.table.twiss
print(f"IBS Growth Rates (horizontal): {tw.ibh[-1]} 1/s")
print(f"IBS Growth Rates (vertical): {tw.ibv[-1]} 1/s")
print(f"IBS Growth Rates (longitudinal): {tw.ibl[-1]} 1/s")
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.09.03  (64 bit, Linux)       +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2024.04.25               +
#   + Execution date: 2025.04.17 14:25:28      +
#   ++++++++++++++++++++++++++++++++++++++++++++
# none = 0;
#
# k1f1.s2 = 0.0202699100251;
#
# const l_bpm = 0;
#
# const l_corr = 0;
#
# k1d1.s2 = -0.019531482603;
#
# k1mrd1.s2 = -0.0229988348489;
#
# k1mrf1.s2 = 0.0180685145227;
#
# k1mrd2.s2 = -0.0313429485012;
#
# k1mrf2.s2 = 0.037036027453;
#
# k1mrd3.s2 = -0.0407069529303;
#
# k1dslf3.a2 = 0.0411186445557;
#
# k2dslf2.a2 := k2dslf1.a2;
#
# k2dslf1.a2 = 0.713599375098;
#
# const l_mb = 11;
#
# th_mb_dis.a2 = 0.00111545441681;
#
# a_dis.s2 = -0.3;
#
# k1dsld2.a2 = -0.0463652253212;
#
# k1dslf2.a2 = 0.0429435972771;
#
# k1dsld1.a2 = -0.0424997203634;
#
# k1dslf1.a2 := k1dsrf1.a1;
#
# k1dsrf1.a1 = 0.0410086983615;
#
# th_mb.a2 = 0.00106406793179;
#
# k1dsld0.a2 := k1dsrd0.a1;
#
# ...
